# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

PATH = os.getcwd()
for _ in range(2):
    PATH = os.path.dirname(PATH)

if PATH not in sys.path:
    sys.path.append(PATH)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from BusinessAnalyticsProject.dataset.eda import create_full_tearsheet

# %%
sns.set_theme()

# %% [markdown]
# ## Create All Figures

# %%
all_train_df = pd.read_csv("../data/processed/all_train.csv", index_col=[0], parse_dates=["Date"])
all_train_df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False     5.727778
# 143         1     2 2010-02-05      50605.27      False     5.727778
# 286         1     3 2010-02-05      13740.12      False     5.727778
# 429         1     4 2010-02-05      39954.04      False     5.727778
# 572         1     5 2010-02-05      32229.38      False     5.727778
# ...       ...   ...        ...           ...        ...          ...
# 421012     45    93 2012-10-26       2487.80      False    14.916667
# 421146     45    94 2012-10-26       5203.31      False    14.916667
# 421289     45    95 2012-10-26      56017.47      False    14.916667
# 421434     45    97 2012-10-26       6817.48      False    14.916667
# 421569     45    98 2012-10-26       1076.80      False    14.916667
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  ...  Unemployment  Type  \
# 0            2.572        NaN        NaN        NaN  ...         8.106     A
# 143          2.572        NaN        NaN        NaN  ...         8.106     A
# 286          2.572        NaN        NaN        NaN  ...         8.106     A
# 429          2.572        NaN        NaN        NaN  ...         8.106     A
# 572          2.572        NaN        NaN        NaN  ...         8.106     A
# ...            ...        ...        ...        ...  ...           ...   ...
# 421012       3.882    4018.91      58.08      100.0  ...         8.667     B
# 421146       3.882    4018.91      58.08      100.0  ...         8.667     B
# 421289       3.882    4018.91      58.08      100.0  ...         8.667     B
# 421434       3.882    4018.91      58.08      100.0  ...         8.667     B
# 421569       3.882    4018.91      58.08      100.0  ...         8.667     B
#
#           Size  Weight MarkDownMean  MarkDownStd  Is_super_bowl  Is_labor_day  \
# 0       151315       1          NaN          NaN          False         False
# 143     151315       1          NaN          NaN          False         False
# 286     151315       1          NaN          NaN          False         False
# 429     151315       1          NaN          NaN          False         False
# 572     151315       1          NaN          NaN          False         False
# ...        ...     ...          ...          ...            ...           ...
# 421012  118221       1     1049.452  1512.607836          False         False
# 421146  118221       1     1049.452  1512.607836          False         False
# 421289  118221       1     1049.452  1512.607836          False         False
# 421434  118221       1     1049.452  1512.607836          False         False
# 421569  118221       1     1049.452  1512.607836          False         False
#
#         Is_thanks_giving  Is_chrismas
# 0                  False        False
# 143                False        False
# 286                False        False
# 429                False        False
# 572                False        False
# ...                  ...          ...
# 421012             False        False
# 421146             False        False
# 421289             False        False
# 421434             False        False
# 421569             False        False
#
# [421570 rows x 23 columns]

# %%
save_dir = "../outputs/EDA/"
create_full_tearsheet(
    all_train_df, 
    save_dir=save_dir
)
# Out:
# Column: Temperature:   0%|                                                    | 0/13 [00:00<?, ?it/s]
# Column: Fuel_Price:  15%|██████▉                                      | 2/13 [00:22<02:01, 11.05s/it]
# Column: MarkDown1:  23%|██████████▌                                   | 3/13 [00:44<02:36, 15.64s/it]
# Column: MarkDown2:  31%|██████████████▏                               | 4/13 [00:45<01:31, 10.16s/it]
# Column: MarkDown3:  38%|█████████████████▋                            | 5/13 [00:45<00:55,  6.91s/it]
# Column: MarkDown4:  46%|█████████████████████▏                        | 6/13 [00:46<00:34,  4.94s/it]
# Column: MarkDown5:  54%|████████████████████████▊                     | 7/13 [00:47<00:21,  3.62s/it]
# Column: CPI:  62%|████████████████████████████████                    | 8/13 [00:48<00:13,  2.78s/it]
# Column: Unemployment:  69%|█████████████████████████████▊             | 9/13 [01:10<00:34,  8.73s/it]
# Column: Size:  77%|██████████████████████████████████████▍           | 10/13 [01:32<00:38, 12.84s/it]
# Column: MarkDownMean:  85%|███████████████████████████████████▌      | 11/13 [01:54<00:31, 15.63s/it]
# Column: MarkDownStd:  92%|███████████████████████████████████████▋   | 12/13 [01:55<00:11, 11.20s/it]
# Column: Dept:   0%|                                                            | 0/4 [00:00<?, ?it/s]
# Column: Type:  25%|█████████████                                       | 1/4 [00:02<00:06,  2.09s/it]
# Column: Holiday_type:  50%|██████████████████████                      | 2/4 [00:02<00:02,  1.22s/it]
